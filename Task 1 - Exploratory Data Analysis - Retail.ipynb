# %% [markdown]
# # By Mohd. Umar Abdullah Abbasi
# # Task 1 - Exploratory Data Analysis - Retail
# # Objective:-
#         # ● To find out the weak areas where you can work to make more profit.
#         # ● What all business problems you can derive by exploring the data?

# %% [markdown]
# # Importing all the Libraries needed

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the DataSet

# %%
sample = pd.read_csv("SampleSuperstore.csv")


#loading the first 10 values of the dataset
sample.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
sample.tail(10)#loads the last ten rows of the data set
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
sample.shape #Number of elments in each Dimension
# Out:
# (9994, 13)

# %%
sample.info() #Checking the Summary of our dateset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
sample.describe() #checks the statistical Data
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
sample.isnull().sum() #Checking missing values
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
sample.duplicated().sum() #checking for duplicate values
# Out:
# 17

# %%
 sample.drop_duplicates  #Dropping the duplicates data
# Out:
# <bound method DataFrame.drop_duplicates of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Deleting Irrelavant Columns

# %%
#col=['Postal Code']
#sample1 = sample.drop(columns=col,axis=1) 
#Deleting the column

# %% [markdown]
# # Checking Statistical Relations between the various rows and columns

# %%
sample.corr() #Correlation between Variables
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sample.cov() #Covariance of Columns
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %%
print(f"Ship Mode unique values are :- {sample['Ship Mode'].unique()} \n\n")

print(f"Region unique values are :- {sample['Region'].unique()} \n\n")

print(f"Segment unique values are :- {sample['Segment'].unique()} \n\n")

print(f"Sub category unique values are :- {sample['Sub-Category'].unique()} \n\n")

print(f"Category unique values are :- {sample['Category'].unique()} \n\n")
# Out:
# Ship Mode unique values are :- ['Second Class' 'Standard Class' 'First Class' 'Same Day']
#
#
# Segment unique values are :- ['Consumer' 'Corporate' 'Home Office']
#
#
# Category unique values are :- ['Furniture' 'Office Supplies' 'Technology']
#
#
# Region unique values are :- ['South' 'West' 'Central' 'East']
#
#
# Sub category unique values are :- ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %%
#Heat Map

plt.figure(figsize=(20,13))
sns.heatmap(sample.corr(), annot=True)
plt.show()

# %% [markdown]
# # Observations
#
# # • There are no outliers in the dataset in terms of sales and profit, but there are in the quantity column.
#
# # • Profit has a strong correlation with sales and profit but there is a negative correlation with discount.

# %% [markdown]
# # Data Visualization

# %%
sns.boxplot(x = sample['Sales'])     #checking the outliers
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
sns.boxplot(x = sample['Profit'])
# Out:
# <AxesSubplot:xlabel='Profit'>

# %%
sns.boxplot(x = sample['Quantity'])
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %%
sns.pairplot(sample)  #plotting a pairplot

# %% [markdown]
# # Obesrvation
# # • There is a positive correlation between profit and sales, but a poor correlation with discount.

# %%
plt.figure(figsize=(20,10))
plt.bar('Sub-Category','Category',data =ss)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Category", size = 20)
# Out:
# Text(0, 0.5, 'Category')

# %%
plt.figure(figsize=(16,9))
plt.bar('Sub-Category','Sales',data =ss)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Sales", size = 20)
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.figure(figsize=(20,6))
plt.bar('Sub-Category','Profit',data =ss)
plt.ylabel("Profit", size = 20)
plt.xlabel("Sub- Category" ,size = 20)
# Out:
# Text(0.5, 0, 'Sub- Category')

# %%
plt.figure(figsize=(20,6))
sample.groupby('Region')['Profit','Sales'].agg(['sum']).plot.bar()
# Out:
# <ipython-input-61-72938f4268ee>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sample.groupby('Region')['Profit','Sales'].agg(['sum']).plot.bar()
# <AxesSubplot:xlabel='Region'>

# %%
plt.figure(figsize=(50,50))
sample.groupby('State')['Profit' , 'Sales'].agg(['sum']).plot.bar()
plt.show()
# Out:
# <ipython-input-65-4cc1d8e3d522>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sample.groupby('State')['Profit' , 'Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize=(60,20))
sample.groupby('Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# <ipython-input-67-81eb1f770116>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sample.groupby('Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# <AxesSubplot:xlabel='Category'>

# %%
plt.figure(figsize=(70,30))
sample.groupby('Sub-Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# <ipython-input-66-cae83e65725b>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sample.groupby('Sub-Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# # Observations
# # • More sales are being found in states such as California, New York, and Texas, implying higher profits.
# # • Fastners, Art and Supplies are rarely sold, so that choice is minimal.

# %%
sns.countplot(x = sample['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# # Observation
# # • The western region is performing better than the rest of the region.

# %%
sns.countplot(x = sample['Segment'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
plt.figure(figsize = (30,10))
sns.barplot(x = sample['Sub-Category'], y = sample['Profit'])
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %% [markdown]
# # Observations
# # • Copiers and machinery may be supplied in greater numbers.

# %%
sample.hist(bins = 60, figsize=(50,30))
plt.show()

# %%
figsize = (20,16)

sns.pairplot(sample,hue = "Sub-Category")

# %%
plt.figure(figsize=(20,15))
plt.scatter(sample['Sales'], ss['Profit'])
plt.xlabel("Sales",size=25)
plt.ylabel("Profit",size=25)
# Out:
# Text(0, 0.5, 'Profit')

# %%
sns.distplot(sample['Sales'],hist = True)
# Out:
# F:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
textprops  = {"fontsize" : 15}
plt.title("Category")
plt.pie(sample['Category'].value_counts(), labels = sample['Category'].value_counts().index, autopct='%1.1f%%', textprops = textprops)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ca186aef70>,
# ...
#  [Text(-0.3496380660429372, 1.0429540846910543, 'Office Supplies'),
#   Text(-0.27974354545119656, -1.0638343615330323, 'Furniture'),
#   Text(0.9197467277963864, -0.6033787837733774, 'Technology')],
#  [Text(-0.1907116723870566, 0.5688840461951205, '60.3%'),
#   Text(-0.15258738842792538, -0.5802732881089266, '21.2%'),
#   Text(0.5016800333434834, -0.32911570024002396, '18.5%')])

# %% [markdown]
# # Observation
# # The most often purchased products are office supplies.

# %%
sample.groupby("State").Profit.agg(["count", "median", "std", "mean","sum","min","max", "var"])
# Out:
#                       count     median         std        mean         sum  \
# State
# Alabama                  61   16.87500  210.901876   94.865989   5786.8253
# Arizona                 224    2.53365  109.266267  -15.303235  -3427.9246
# Arkansas                 60   18.34080  123.249880   66.811452   4008.6871
# California             2001   13.30560   97.691593   38.171608  76381.3871
# Colorado                182    3.12480  276.424024  -35.867351  -6527.8579
# Connecticut              82   12.18310   66.138081   42.823071   3511.4918
# Delaware                 96   19.19700  518.953513  103.930988   9977.3748
# District of Columbia     10   14.52720  213.461353  105.958930   1059.5893
# Florida                 383    2.93400  126.324165   -8.875461  -3399.3017
# Georgia                 184   22.24690  283.026694   88.315453  16250.0433
# Idaho                    21   14.70000   63.027976   39.367767    826.7231
# ...

# %% [markdown]
# # Conclusion
# # Through cutting costs and focusing on the selling of office supplies and furniture, the business would do good and even better.
